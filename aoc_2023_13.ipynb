# %% [markdown]
# # Code Setup

# %%
import numpy as np

from utils.import_puzzle_input import load_input
from utils.import_puzzle_input import split_puzzle_input

# Load the autoreload extension
# %load_ext autoreload

# Set autoreload to automatically reload modules before executing code
# %autoreload 2

# %%
puzzle_input = load_input(2023, 13)
# Out:
# saved puzzle input ./data/puzzle_input_2023_13.pkl

# %%
puzzle_input_split = split_puzzle_input(puzzle_input)
puzzle_input_split
# Out:
# ['.##..##',
#  '###..##',
#  '#..##..',
#  '#..##..',
#  '##....#',
#  '.##..##',
#  '##.##.#',
#  '###..##',
#  '.##..##',
#  '..#..#.',
#  '.#.##.#',
#  '',
#  '#...#..##.#..##..',
#  '..###.#.##..#..##',
#  '.....#...#####.##',
#  '.....#...#####.##',
#  '..###.#.##..#..##',
#  '#...#..##.#..##..',
#  '.##.#.###.###..##',
#  '.###.#.#..#.#.#.#',
#  '##...#.#.....#.#.',
#  '.#...#..##.##..#.',
#  '######.#..#..##.#',
#  '#######.##.....#.',
#  '####.##.##.....#.',
#  '',
#  '####.##.#######',
#  '.####..####....',
#  '####.##.#######',
#  '.###.##.###.##.',
#  '.##..##..##....',
#  '.#...##...#.##.',
#  '#..######..####',
#  '#..#....#..####',
#  '.###.##.###.##.',
#  '#.#..##.##.####',
#  '#.#.#..#.#.#..#',
#  '####....#######',
#  '.##......##.##.',
#  '',
#  '#..#.###..###.#',
#  '.###..#....#..#',
#  '.###.#..##..#.#',
#  '..###........##',
#  '.###.#.#..#.#.#',
#  '.....##....##..',
#  '##..#.#.##.#.#.',
#  '##..#.#.##.#.#.',
#  '.#...##....##..',
#  '.###.#.#..#.#.#',
#  '..###........##',
#  '',
#  '.##.#.#',
#  '###..##',
#  '#..#.#.',
#  '#..#...',
#  '#..#...',
#  '#.##.#.',
#  '###..##',
#  '.##.#.#',
#  '.##.#.#',
#  '###..##',
#  '#.##.#.',
#  '#..#...',
#  '#..#...',
#  '#..#.#.',
#  '###..##',
#  '.##.#.#',
#  '....#..',
#  '',
#  '#.#..##',
#  '#.#.#.#',
#  '...##..',
#  '#..###.',
#  '.#..##.',
#  '.#####.',
#  '.#####.',
#  '.#..##.',
#  '#..###.',
#  '...##..',
#  '#.#.#.#',
#  '#.##.##',
#  '#.##.##',
#  '',
#  '....###....###.',
#  '#..############',
#  '#..#.##....##.#',
#  '######..##..###',
#  '.##..##.##.##..',
#  '....#.#.##.#.#.',
#  '.##..##.##.##..',
#  '.##.###....####',
#  '.##...######...',
#  '#..#..#....#..#',
#  '.##....#..#....',
#  '.##.#........#.',
#  '.##.##.#..#.##.',
#  '.##..##.##.##..',
#  '#..###..##..###',
#  '',
#  '########.##..#.',
#  '##....##....##.',
#  '.#.##.#..##..##',
#  '...........#..#',
#  '#######.#.###..',
#  '#.####.###....#',
#  '##....###....##',
#  '...##....#.#...',
#  '##....##.######',
#  '##....##.######',
#  '...##....#.#...',
#  '##....###....##',
#  '#.####.###....#',
#  '',
#  '#.###.#..',
#  '#.###.#..',
#  '..##.#.##',
#  '#.####.#.',
#  '#####...#',
#  '#.##.##..',
#  '..##.#...',
#  '##...###.',
#  '.#....#.#',
#  '#..#...##',
#  '#..#.#.##',
#  '',
#  '.#######..###',
#  '...##...##...',
#  '###..#####...',
#  '###..#####...',
#  '...##...##...',
#  '.#######..###',
#  '.#....#.##.#.',
#  '',
#  '.###.##..##.###..',
#  '...#...##...#....',
#  '..#.#.####.#.#...',
#  '.#...#...##...#.#',
#  '.....#....#.....#',
#  '#.##.##..##.##.#.',
#  '...#.######.#...#',
#  '#.#..#.##.#..#.#.',
#  '....##....##....#',
#  '#######..########',
#  '##.#..####..#.##.',
#  '#..#..#..#..#..##',
#  '#..#..#..#..#..##',
#  '',
#  '.#.##....##',
#  '....#....#.',
#  '.#.#.####.#',
#  '.####....##',
#  '###........',
#  '#.#..####..',
#  '#.##.####..',
#  '##.#......#',
#  '...#.####.#',
#  '...#.####.#',
#  '##.#......#',
#  '#.##.####..',
#  '#.#..####..',
#  '',
#  '###.#...###',
#  '...#..##.#.',
#  '.##.#..##.#',
#  '.##.###....',
#  '..#.##..#..',
#  '#..#.#.#.##',
#  '.#.#..#..##',
#  '...#..#..##',
#  '#..#.#.#.##',
#  '..#.##..#..',
#  '.##.###....',
#  '.##.#..##.#',
#  '...#..##.#.',
#  '###.#...###',
#  '###.#...###',
#  '',
#  '.##.##.',
#  '.#.#..#',
#  '.#.####',
#  '##..##.',
#  '#.#....',
#  '...#..#',
#  '.######',
#  '...#..#',
#  '#...##.',
#  '.#.####',
#  '.#.####',
#  '#.#.##.',
#  '...#..#',
#  '',
#  '.......###..#.#.#',
#  '#.##.#......###.#',
#  '.####.##.#.#.##.#',
#  '.####.##..####..#',
#  '#.##.##......###.',
#  '......##..#......',
#  '.####.#.....#....',
#  '##..###.#.#...###',
#  '##..##..#.#...###',
#  '',
#  '..##.##.##.',
#  '#..#.#.####',
#  '.#.#...####',
#  '.#..#.##..#',
#  '..#####....',
#  '#.####.....',
#  '##.##...##.',
#  '##.##...##.',
#  '#.####.....',
#  '..#####....',
#  '.#..#.##..#',
#  '##.#...####',
#  '#..#.#.####',
#  '..##.##.##.',
#  '#..#.###..#',
#  '###.###.##.',
#  '####.##....',
#  '',
#  '#.#.###',
#  '##.....',
#  '.#..##.',
#  '.###..#',
#  '.###..#',
#  '.#..##.',
#  '##.....',
#  '#.#.###',
#  '###.###',
#  '',
#  '##..#...#.###',
#  '.#.##.#...###',
#  '##.#..###..##',
#  '..........###',
#  '.#.###.....##',
#  '#...#.#.#..##',
#  '#.##.#####...',
#  '.#.##..###...',
#  '...##..##.###',
#  '##...........',
#  '#####..####..',
#  '#####..####..',
#  '#............',
#  '',
#  '###.###',
#  '....###',
#  '.##..##',
#  '...####',
#  '##.####',
#  '#...#..',
#  '###.#..',
#  '..###..',
#  '...#.##',
#  '.#.#.##',
#  '..###..',
#  '',
#  '#.######.##',
#  '...####....',
#  '...#..#....',
#  '.#..##..#..',
#  '##.#..#.###',
#  '#.#....#.##',
#  '#.#......##',
#  '####..#####',
#  '#.#....#.##',
#  '.#.####.#..',
#  '#.##..##.##',
#  '##..##..###',
#  '.##.##.##..',
#  '',
#  '..###..###...##',
#  '...#....#....##',
#  '.#........#.###',
#  '..#.#..#.#..###',
#  '#...#..#...##..',
#  '###.#..#.###.##',
#  '##############.',
#  '#.#.#..#.#.#.##',
#  '..##.##.##.....',
#  '',
#  '##....###...###',
#  '.##..##.##..###',
#  '##....##...####',
#  '##.##.###.#....',
#  '#..##..##.##.#.',
#  '.#....#.###.##.',
#  '##....###...###',
#  '##....###...###',
#  '.#....#.###.##.',
#  '#..##..#####.#.',
#  '##.##.###.#....',
#  '##....##...####',
#  '.##..##.##..###',
#  '##....###...###',
#  '..####..#...###',
#  '.######.#.##.##',
#  '.##..##...####.',
#  '',
#  '.#.#...',
#  '.#.#...',
#  '#.#..##',
#  '.####..',
#  '...###.',
#  '#..##..',
#  '##.#.#.',
#  '....#.#',
#  '....#.#',
#  '##.#.#.',
#  '##.##..',
#  '...###.',
#  '.####..',
#  '',
#  '..##....##.',
#  '###.#..####',
#  '##........#',
#  '####.##.###',
#  '...#....#..',
#  '####.##.###',
#  '##.######.#',
#  '',
#  '..#......#....#..',
#  '.#.#....#.#..#.#.',
#  '..#.#..#.#....#.#',
#  '##.#.##.#.####.#.',
#  '...##..#........#',
#  '.#..####..#..#..#',
#  '.#.#.##.#.#..#.#.',
#  '',
#  '.#.#..#...#..',
#  '##...#####.#.',
#  '...#...##.#..',
#  '..##.#.#..##.',
#  '##...#..####.',
#  '####.##.#..#.',
#  '...#.#.####..',
#  '..##.#..#..#.',
#  '#######...#.#',
#  '####..#...###',
#  '####.######.#',
#  '##..##...##.#',
#  '....#..#.##.#',
#  '....#..#.##.#',
#  '##..##...##.#',
#  '####.######.#',
#  '####..#...###',
#  '',
#  '##..##.#.##.#.#',
#  '..###..######..',
#  '..#...#..##..#.',
#  '####.##.####.##',
#  '###.#..#.##.#..',
#  '..###....##....',
#  '###.#....##....',
#  '.....##########',
#  '###..###....###',
#  '####.###.##.###',
#  '..#####.#..####',
#  '##.#####.##.###',
#  '##.#..########.',
#  '',
#  '##.####',
#  '###.#.#',
#  '...####',
#  '######.',
#  '#####..',
#  '###....',
#  '###...#',
#  '..###..',
#  '##..###',
#  '..###.#',
#  '####.#.',
#  '......#',
#  '......#',
#  '####.#.',
#  '..###.#',
#  '##.####',
#  '..###..',
#  '',
#  '....#.##..##.#.',
#  '####..#....#..#',
#  '#..#....##....#',
#  '......#.##.#...',
#  '.##.#........#.',
#  '.##...##..##...',
#  '#..###.#..#.###',
#  '#..###..##..#.#',
#  '#..###......###',
#  '#..#.#.####.#.#',
#  '.......####....',
#  '....##......##.',
#  '.##..#.#..#.#..',
#  '#..#.#.####.#.#',
#  '.....##....##..',
#  '',
#  '.#......#.####..#',
#  '#..####..#..##..#',
#  '.#.####.#..#..#..',
#  '#...##...#.#.####',
#  '##########.......',
#  '#..####..#....##.',
#  '.##.##.##.#.#.##.',
#  '#........#....##.',
#  '..#.##.#....#.##.',
#  '',
#  '###.##.#....#.##.',
#  '..####.##..##.###',
#  '###..#..####..#..',
#  '..#..............',
#  '###...##....##...',
#  '..#.###..##..###.',
#  '...#.#...##...#.#',
#  '##...#.#....#.#..',
#  '###.##..####..##.',
#  '...##.#......#.##',
#  '...#.#...#....#.#',
#  '####.....##.....#',
#  '###...##.##.##...',
#  '####.####..####.#',
#  '....#####..#####.',
#  '',
#  '#.##.#..#',
#  '##...#.##',
#  '##....##.',
#  '....##...',
#  '....###..',
#  '##....##.',
#  '##...#.##',
#  '#.##.#..#',
#  '#.##.#..#',
#  '',
#  '.##.#......#.',
#  '#####.####.##',
#  '#..#...##...#',
#  '.##.###.####.',
#  '....#..##..#.',
#  '#.##..####..#',
#  '....###..###.',
#  '#....######..',
#  '##....#..#...',
#  '#.##.#....#.#',
#  '...#...##...#',
#  '..#.########.',
#  '..#.########.',
#  '...#...##...#',
#  '#.##.#....#.#',
#  '',
#  '.#.#.#..#....',
#  '.#.#.#..#....',
#  '#.#.###.#....',
#  '#......###..#',
#  '...##..#.#..#',
#  '.##..###.#.##',
#  '.#.#.##.#.###',
#  '##..##..#.#.#',
#  '..#..######.#',
#  '#..#.####.#..',
#  '..######.#.##',
#  '..######.#.##',
#  '#..#.#.##.#..',
#  '',
#  '##.###.....#.',
#  '##.#..####...',
#  '##...###.##.#',
#  '###..###..#.#',
#  '...##...#..##',
#  '...##...#..##',
#  '###..###.##.#',
#  '##...###.##.#',
#  '##.#..####...',
#  '##.###.....#.',
#  '##...#.##.#.#',
#  '..###..#.#...',
#  '##.###...#..#',
#  '',
#  '..#.##....##.#...',
#  '###..######..####',
#  '..#.###..###.#...',
#  '....##.##.##.....',
#  '.###..#..#..###..',
#  '..#####..######..',
#  '######....#######',
#  '##.###....###.###',
#  '#.#.#.#..#.#.#.##',
#  '###.#.####.#.####',
#  '.##.#..##..#.##..',
#  '',
#  '.#..##..##.',
#  '..#.#....#.',
#  '.....####..',
#  '#..###..###',
#  '###..#.##..',
#  '####.#..#.#',
#  '####.#..#.#',
#  '',
#  '#.##.##',
#  '..##.##',
#  '..##.##',
#  '#.##.##',
#  '.#....#',
#  '#.#....',
#  '##.##.#',
#  '..###..',
#  '...###.',
#  '',
#  '####.#..#.#',
#  '....######.',
#  '......##...',
#  '.##.######.',
#  '......##...',
#  '.##.#.##.#.',
#  '.##........',
#  '....######.',
#  '.##.....#..',
#  '',
#  '##....###',
#  '#...#####',
#  '#.###...#',
#  '.#..#..##',
#  '....####.',
#  '...##.##.',
#  '##...#.#.',
#  '##...#.#.',
#  '...##.##.',
#  '....####.',
#  '.#..#..##',
#  '#.###...#',
#  '#...#####',
#  '##.#..###',
#  '##.#..###',
#  '',
#  '#.##..##.#.#.####',
#  '..........##.....',
#  '..######..####..#',
#  '..######....#.##.',
#  '#.##..##.##.##.##',
#  '..##..##...#.....',
#  '#.##..##.###.....',
#  '###....###...#..#',
#  '#........###..##.',
#  '#...##...##.#####',
#  '....##......#####',
#  '..##..##..#..#..#',
#  '#.#.##.#.#####..#',
#  '',
#  '##.##.##...###.',
#  '#.####.##..###.',
#  '..####..#......',
#  '##.##.##.#..#..',
#  '..####...#...##',
#  '........#.#.#.#',
#  '..#..#..#...##.',
#  '##.##.###..##.#',
#  '##.##.###...###',
#  '###..###.#...##',
#  '..#..#...##..#.',
#  '',
#  '#...#..#....#..',
#  '.#..###..##..##',
#  '##..#..##..##..',
#  '.##.#####..####',
#  '.#..#..#....#..',
#  '.#.###..#..#..#',
#  '.###.##########',
#  '.#......#..#...',
#  '#####..#....#..',
#  '.#.#...#.##.#..',
#  '.######..##..##',
#  '#.#..##.#..#.##',
#  '........####...',
#  '',
#  '##.#.#.##',
#  '....#....',
#  '######...',
#  '##.##.##.',
#  '###....#.',
#  '....##.##',
#  '##.#.....',
#  '....#..##',
#  '...######',
#  '....#####',
#  '....#..##',
#  '',
#  '#.#.#.#.###.#....',
#  '##..###..##.#....',
#  '.#.#.##.###.#####',
#  '..###....###.##..',
#  '#..#.#.##..######',
#  '#.#.###..###.....',
#  '.####...######...',
#  '##..#.#.#..#.#.##',
#  '#.####.##...#.###',
#  '#.##.#.##.###..##',
#  '.##...#.##.....##',
#  '.....###.#.###...',
#  '.#.##..#....#..##',
#  '.#.##..#.#..#..##',
#  '.....###.#.###...',
#  '',
#  '###...#..##',
#  '..#.#...###',
#  '#.#.##.....',
#  '...#...####',
#  '##.#...#.##',
#  '......#..##',
#  '#..#.##....',
#  '...###..#..',
#  '..#.##.##..',
#  '..#.##.##..',
#  '.#.###..#..',
#  '#..#.##....',
#  '......#..##',
#  '',
#  '##.####',
#  '#..##..',
#  '..##..#',
#  '#..#...',
#  '....#.#',
#  '##.##..',
#  '#.##..#',
#  '#.#.#..',
#  '#.#.#..',
#  '#.##..#',
#  '#..##..',
#  '....#.#',
#  '#..#...',
#  '..##..#',
#  '#..##..',
#  '##.####',
#  '##.####',
#  '',
#  '#.##.#####.####.#',
#  '.#..####.#......#',
#  '#..###.##...##...',
#  '.##.....####..###',
#  '##..###..########',
#  '#.##.#....#.##.#.',
#  '#.##.#....#.##.#.',
#  '##..###..########',
#  '.##.....####..###',
#  '#..###.##...##...',
#  '.#..###..#......#',
#  '',
#  '.###..#.##.#.#.',
#  '#...####...##.#',
#  '...#.####..#.##',
#  '#..###...#####.',
#  '#..###...#####.',
#  '...#.####..#.##',
#  '#...####...##.#',
#  '.###..####.#.#.',
#  '#.#..#.####..##',
#  '#..#####..#..##',
#  '#..#####..#..##',
#  '',
#  '#.#....#####..#',
#  '..###..##...##.',
#  '..#.###.##.....',
#  '...##...#...##.',
#  '...##...#...##.',
#  '..#.###.##.....',
#  '..###..##...##.',
#  '#.#....#####..#',
#  '.#.#......#.#..',
#  '#....##....#..#',
#  '##.#.#.#####..#',
#  '',
#  '.#..###..#...#.##',
#  '###.##.#.#....#..',
#  '###.##.###....#..',
#  '.#..###..#...#.##',
#  '##..#..#.#.##....',
#  '#....#....###.#..',
#  '....#.##..###..##',
#  '.#.###.#..#..#...',
#  '.#..##.##.#.#..##',
#  '',
#  '...##...#..',
#  '##.##.####.',
#  '##....##..#',
#  '..#..#.....',
#  '#.#..###...',
#  '#..##..#..#',
#  '.######..#.',
#  '##....##..#',
#  '...##.....#',
#  '...##.....#',
#  '##....##..#',
#  '',
#  '#....#......#..',
#  '#.##.########.#',
#  '##..##########.',
#  '##..##.#..#.##.',
#  '.####..####..#.',
#  '#.##.#.#..#.#.#',
#  '#######.##.####',
#  '######......###',
#  '.####.#.##.#.##',
#  '.......####....',
#  '##..####..####.',
#  '.#..#.#.##.#.#.',
#  '.####.#....#.##',
#  '',
#  '########...##..',
#  '#......###....#',
#  '###..##########',
#  '#########..##..',
#  '#..##..#...##..',
#  '........#..##..',
#  '.#....#.##.##.#',
#  '.#....#.##.##.#',
#  '.#....#........',
#  '...##......##..',
#  '..#..#...#.##.#',
#  '.#....#.#..##..',
#  '#.####.###.##.#',
#  '###..###..####.',
#  '##.######..##..',
#  '',
#  '..##.....####..',
#  '..#.#.#..#..#..',
#  '..###.######.##',
#  '###..#.##....##',
#  '....####..##..#',
#  '##.###.########',
#  '..########..###',
#  '...#..###....##',
#  '....###.#.##.#.',
#  '##....####..###',
#  '##.#..###.##.##',
#  '',
#  '.####.#.####..#..',
#  '.#.....#..#######',
#  '######.###..#..##',
#  '.##.....#..#.#.##',
#  '##...#..#.####.##',
#  '..##...#.####.###',
#  '#.#..####...###..',
#  '#.#.##..#.#...#..',
#  '..##..#.#..#.#...',
#  '#..##..#....##...',
#  '.##.....##.#.#.##',
#  '.###..###....#.##',
#  '.###..####...#.##',
#  '',
#  '..#..####..#.',
#  '##.#.#..#.#..',
#  '...#..##..#..',
#  '##.#......#.#',
#  '###.##..##.##',
#  '...########..',
#  '..##..##..##.',
#  '##.###..###.#',
#  '..##..##..##.',
#  '',
#  '.##..#..#.#..##..',
#  '.#.##....##.#..#.',
#  '..###......##..##',
#  '##..######.......',
#  '.#######.........',
#  '####...#..#######',
#  '...###..##...##..',
#  '....#.#...##....#',
#  '.#.##..#.####..##',
#  '##...###.##..##..',
#  '##...###.##..##..',
#  '.####..#.####..##',
#  '....#.#...##....#',
#  '',
#  '#..##.####.',
#  '#..##.####.',
#  '#...#.####.',
#  '#####..##..',
#  '.#..##.##.#',
#  '...#..#..#.',
#  '.......##..',
#  '.##.#......',
#  '#...#......',
#  '##.#..#..#.',
#  '##...#....#',
#  '...########',
#  '#.##..#..#.',
#  '###..#.##.#',
#  '.....######',
#  '#..#....#..',
#  '#.#.##.##.#',
#  '',
#  '##..#.#....',
#  '.####..#.##',
#  '.#.#.#..#.#',
#  '.#.#.#..#.#',
#  '.####..#.##',
#  '##..#.#....',
#  '#####......',
#  '.###..##.##',
#  '##..##.###.',
#  '#..#....#..',
#  '##.#####.##',
#  '.###...###.',
#  '..##...###.',
#  '##.#####.##',
#  '#..#....#..',
#  '',
#  '..###....###.',
#  '####......###',
#  '...#..##..#..',
#  '....##..##...',
#  '..####..####.',
#  '...#..##..#..',
#  '..#.#....#.#.',
#  '###..#..#..##',
#  '..#.####.#.#.',
#  '##..#....#..#',
#  '#####.##.####',
#  '....##..##...',
#  '##...####...#',
#  '###..#..#..##',
#  '..#...##...#.',
#  '',
#  '##.#...##.##..#',
#  '.#..##.##.#.##.',
#  '###.#..###.....',
#  '###.#..###.....',
#  '.#..##.##.#.##.',
#  '#..#...##.##..#',
#  '##.#####.#..##.',
#  '#.#.##..#.#....',
#  '#.#....####....',
#  '.######.#...##.',
#  '...#.##.#..####',
#  '..##....###.##.',
#  '..#..##.#######',
#  '.#..##...#.#..#',
#  '#..###.........',
#  '.##..#.#.###..#',
#  '######.##.##..#',
#  '',
#  '##.###..##.######',
#  '##.##...#..##..##',
#  '#..#.....##.####.',
#  '..#.#...#.##....#',
#  '##..##.##.###..##',
#  '######..#########',
#  '.#..##....#.####.',
#  '.#....###..##..##',
#  '.....##.....#..#.',
#  '#....#....#..##..',
#  '#..#...#.........',
#  '#..#...##.###..##',
#  '#..#.#.##.###..##',
#  '',
#  '..####.',
#  '##....#',
#  '##....#',
#  '..####.',
#  '#.#..#.',
#  '.#.##.#',
#  '...##..',
#  '##.##.#',
#  '#..##..',
#  '#.####.',
#  '#......',
#  '##....#',
#  '.######',
#  '..#####',
#  '##....#',
#  '###..##',
#  '#.####.',
#  '',
#  '...#..##..#...###',
#  '.#..#....#..#...#',
#  '##.########.##.##',
#  '#...######...#...',
#  '##.#..##..#.##...',
#  '..#.######.#...##',
#  '####.##.#.######.',
#  '##....##....###..',
#  '##.########.##.#.',
#  '#.#.##..##.#.#.##',
#  '..#.#....#.#.....',
#  '.....####.....##.',
#  '#.#.##..##.#.###.',
#  '.#.#.#..#.#.#.##.',
#  '.#.#.#..#.#.#.##.',
#  '',
#  '##....#',
#  '#.#..#.',
#  '.#.##.#',
#  '.#.##.#',
#  '..#..#.',
#  '##....#',
#  '.######',
#  '',
#  '#.###..##.##.',
#  '#....#.#.....',
#  '###..#.####..',
#  '#.....#.#.###',
#  '#...#..#.#...',
#  '#.#..##....##',
#  '####.#..#....',
#  '.###.#.#.....',
#  '.###.#.#.....',
#  '####.#..#....',
#  '#.#..##....##',
#  '#...#..#.#...',
#  '#.....#.#.###',
#  '###..#.####..',
#  '#....#.#.....',
#  '',
#  '..#....####..',
#  '..##...####..',
#  '#.#.##.#..#.#',
#  '#..#..#..#.#.',
#  '###.....##...',
#  '...###.####.#',
#  '##.#.#..##..#',
#  '##.#.#..##..#',
#  '...###.####.#',
#  '###.....##...',
#  '#..#..#..#.#.',
#  '',
#  '.##..#.#..#..#.',
#  '#..#..##.#....#',
#  '.##...#..#.##.#',
#  '#.####.#.##..##',
#  '....#.#..#.##.#',
#  '#######.#......',
#  '....#...#.####.',
#  '....##.#.......',
#  '.......##.#..#.',
#  '####.#....#..#.',
#  '#####..#.######',
#  '####.#..#......',
#  '.##.#..#..#..#.',
#  '#..#####..####.',
#  '.##.....#......',
#  '.##.###...#..#.',
#  '....##.#...##..',
#  '',
#  '##.#..#',
#  '.##....',
#  '..##..#',
#  '.#.####',
#  '##.#..#',
#  '.##....',
#  '.######',
#  '#.#.##.',
#  '###....',
#  '.##....',
#  '.##....',
#  '###....',
#  '#.#.##.',
#  '.######',
#  '.##....',
#  '#..#..#',
#  '.#.####',
#  '',
#  '##......###..###.',
#  '..#....#...##...#',
#  '#.#.##.#.#....#.#',
#  '#........######..',
#  '.##....##.####.##',
#  '.#.####.#..##..#.',
#  '##..##..##....###',
#  '..........####...',
#  '...####....##....',
#  '',
#  '##...##.##.##...#',
#  '###..##.##.##..##',
#  '#####.##..##.####',
#  '##.##........##.#',
#  '###.####..####.##',
#  '...##.#....#.##..',
#  '...#..######..#..',
#  '####.#..##..#.###',
#  '..##..#.##.#..###',
#  '',
#  '..###.##.',
#  '.#####..#',
#  '....#####',
#  '##.#..###',
#  '#.##..##.',
#  '##.###.#.',
#  '.#..##...',
#  '.#..##...',
#  '##.###.#.',
#  '#.##..##.',
#  '##.#..###',
#  '....#####',
#  '.#####..#',
#  '..###.##.',
#  '..###.##.',
#  '.#####...',
#  '....#####',
#  '',
#  '........#',
#  '#.####.##',
#  '.#....#.#',
#  '........#',
#  '...##....',
#  '...##....',
#  ...]

# %% [markdown]
# # Problem Setup

# %% [markdown]
# # General thoughts

# %% [markdown]
# # Solutions

# %% [markdown]
# ## Solution 1:

# %% [markdown]
# ### Explanation of method

# %% [markdown]
# #### Remarks

# %% [markdown]
# ### Implementation

# %% [markdown]
# ### Checking runtime

# %% [markdown]
# #### Benchmarking

# %% [markdown]
# #### Runtime profiling

# %% [markdown]
# ## Solution 2:

# %% [markdown]
# # Experimental
